# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
url = "http://bit.ly/w-data"
data = pd.read_csv(url)
print("Data imported successfully")
# Out:
# Data imported successfully

# %%
print(data.head())
print(data.describe())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
plt.scatter(data['Hours'], data['Scores'], color='blue')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
X = data[['Hours']]
y = data['Scores']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# Compare actual vs predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
# Out:
#     Actual  Predicted
# 5       20  16.884145
# 2       27  33.732261
# 19      69  75.357018
# 16      30  26.794801
# 11      62  60.491033

# %%
y_pred = model.predict(X_test)

# Compare actual vs predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df)
# Out:
#     Actual  Predicted
# 5       20  16.884145
# 2       27  33.732261
# 19      69  75.357018
# 16      30  26.794801
# 11      62  60.491033

# %%
hours = np.array([[9.25]])
predicted_score = model.predict(hours)
print(f"Predicted score for a student studying 9.25 hours/day: {predicted_score[0]:.2f}")
# Out:
# Predicted score for a student studying 9.25 hours/day: 93.69
# C:\Users\salma\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.title('Hours vs Percentage (Regression Line)')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()
